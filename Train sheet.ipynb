# %%
import pandas as pd

# %%
#Incase you don't have pandas installed
pip install pandas

# %%
data = pd.read_csv("C:/Users/Uchenna Umeji/Desktop/Test/data2.csv", encoding="8859")

# %%
data.info
# Out:
# <bound method DataFrame.info of                          name                         album  \
# 0                      Sparky            Mandy & The Jungle
# 1                  shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                       LITT!                         LITT!
# 3    Confident / Feeling Cool               Enjoy Your Life
# 4                  wanted you                         rare.
# ..                        ...                           ...
# 525                   Kwaroro                       Kwaroro
# 526             Concert Party                   Afro Escape
# 527                      Loko                    Applaudise
# 528                      Gift                    Applaudise
# 529                    Macoma                    Applaudise
#
#                   artist artist_top_genre  release_date  length  popularity  \
# 0          Cruel Santino  alternative r&b          2019  144000          48
# ...

# %%
data.shape
# Out:
# (530, 16)

# %%
data.ndim
# Out:
# 2

# %%
data.head()
# Out:
#                        name                         album  \
# 0                    Sparky            Mandy & The Jungle
# 1                shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                     LITT!                         LITT!
# 3  Confident / Feeling Cool               Enjoy Your Life
# 4                wanted you                         rare.
#
#                 artist artist_top_genre  release_date  length  popularity  \
# 0        Cruel Santino  alternative r&b          2019  144000          48
# 1  Odunsi (The Engine)          afropop          2020   89488          30
# 2                AYLÃ        indie r&b          2018  207758          40
# 3           Lady Donli     nigerian pop          2019  175135          14
# 4  Odunsi (The Engine)          afropop          2018  152049          25
#
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# ...

# %%
data.tail()
# Out:
#               name        album           artist artist_top_genre  \
# 525        Kwaroro      Kwaroro       J. Martins   afro dancehall
# 526  Concert Party  Afro Escape  Various Artists   afro dancehall
# 527           Loko   Applaudise           Iyanya   afro dancehall
# 528           Gift   Applaudise           Iyanya   afro dancehall
# 529         Macoma   Applaudise           Iyanya   afro dancehall
#
#      release_date  length  popularity  danceability  acousticness  energy  \
# 525          2015  193960          10         0.735         0.632   0.918
# 526          2015  252708           0         0.602         0.177   0.883
# 527          2015  223159           0         0.729         0.238   0.864
# 528          2015  278280           0         0.809         0.049   0.806
# 529          2015  213426           0         0.816         0.114   0.961
#
#      instrumentalness  liveness  loudness  speechiness    tempo  \
# ...

# %%
data.head(15)
# Out:
#                             name                         album  \
# 0                         Sparky            Mandy & The Jungle
# 1                     shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                          LITT!                         LITT!
# 3       Confident / Feeling Cool               Enjoy Your Life
# 4                     wanted you                         rare.
# 5                         Kasala                      Pioneers
# 6                        Pull Up             Everything Pretty
# 7                   take a break                         rare.
# 8                           Cash               Enjoy Your Life
# 9                      SATISFIED                        GEMINI
# 10                       Morocco            Mandy & The Jungle
# 11                 luv in a mosh  EVERYTHING YOU HEARD IS TRUE
# 12                    Raw Dinner            Mandy & The Jungle
# 13                          Waka                      Wildfire
# ...

# %%
data['artist']
# Out:
# 0            Cruel Santino
# 1      Odunsi (The Engine)
# 2                    AYLÃ
# 3               Lady Donli
# 4      Odunsi (The Engine)
#               ...
# 525             J. Martins
# 526        Various Artists
# 527                 Iyanya
# 528                 Iyanya
# 529                 Iyanya
# Name: artist, Length: 530, dtype: object

# %%
data['artist']
# Out:
# 0            Cruel Santino
# 1      Odunsi (The Engine)
# 2                    AYLÃ
# 3               Lady Donli
# 4      Odunsi (The Engine)
#               ...
# 525             J. Martins
# 526        Various Artists
# 527                 Iyanya
# 528                 Iyanya
# 529                 Iyanya
# Name: artist, Length: 530, dtype: object

# %%
data.isnull()
# Out:
#       name  album  artist  artist_top_genre  release_date  length  popularity  \
# 0    False  False   False             False         False   False       False
# 1    False  False   False             False         False   False       False
# 2    False  False   False             False         False   False       False
# 3    False  False   False             False         False   False       False
# 4    False  False   False             False         False   False       False
# ..     ...    ...     ...               ...           ...     ...         ...
# 525  False  False   False             False         False   False       False
# 526  False  False   False             False         False   False       False
# 527  False  False   False             False         False   False       False
# 528  False  False   False             False         False   False       False
# 529  False  False   False             False         False   False       False
#
# ...

# %%
data.isnull().count()
# Out:
# name                530
# album               530
# artist              530
# artist_top_genre    530
# release_date        530
# length              530
# popularity          530
# danceability        530
# acousticness        530
# energy              530
# instrumentalness    530
# liveness            530
# loudness            530
# speechiness         530
# tempo               530
# time_signature      530
# dtype: int64

# %%
data['tempo'].mean()
# Out:
# 116.48786415094337

# %%
mmean = data['tempo'].mean()

print(mmean)
# Out:
# 116.48786415094337

# %%
data['3'].fillna(mmean, implace=True)

# %%
data.groupby('artist').count()
# Out:
#                name  album  artist_top_genre  release_date  length  \
# artist
# 2Baba             6      6                 6             6       6
# 9ice              3      3                 3             3       3
# AYLÃ             4      4                 4             4       4
# Adekunle Gold     4      4                 4             4       4
# Afro B            1      1                 1             1       1
# ...             ...    ...               ...           ...     ...
# Yemi Alade        7      7                 7             7       7
# Yung L            1      1                 1             1       1
# Zlatan            1      1                 1             1       1
# chike             1      1                 1             1       1
# prettyboydo       2      2                 2             2       2
#
#                popularity  danceability  acousticness  energy  \
# artist
# 2Baba                   6             6             6       6
# ...

# %%
data['album'].describe()
# Out:
# count     530
# unique    428
# top       Ayo
# freq        6
# Name: album, dtype: object

# %%
list = [[2,3,4], [6,8,9]]

list[1][1:]
# Out:
# [8, 9]

# %%
list1 = [2,3,4,6,8,9]

list1[2:3:2]
# Out:
# [4]

# %%
data.groupby('artist').count()
# Out:
#                name  album  artist_top_genre  release_date  length  \
# artist
# 2Baba             6      6                 6             6       6
# 9ice              3      3                 3             3       3
# AYLÃ             4      4                 4             4       4
# Adekunle Gold     4      4                 4             4       4
# Afro B            1      1                 1             1       1
# ...             ...    ...               ...           ...     ...
# Yemi Alade        7      7                 7             7       7
# Yung L            1      1                 1             1       1
# Zlatan            1      1                 1             1       1
# chike             1      1                 1             1       1
# prettyboydo       2      2                 2             2       2
#
#                popularity  danceability  acousticness  energy  \
# artist
# 2Baba                   6             6             6       6
# ...

# %%
data.groupby('artist')['artist'].count()

unique = data.groupby('artist').count()

print(unique)
# Out:
#                name  album  artist_top_genre  release_date  length  \
# artist
# 2Baba             6      6                 6             6       6
# 9ice              3      3                 3             3       3
# AYLÃ             4      4                 4             4       4
# Adekunle Gold     4      4                 4             4       4
# Afro B            1      1                 1             1       1
# ...             ...    ...               ...           ...     ...
# Yemi Alade        7      7                 7             7       7
# Yung L            1      1                 1             1       1
# Zlatan            1      1                 1             1       1
# chike             1      1                 1             1       1
# prettyboydo       2      2                 2             2       2
#
#                popularity  danceability  acousticness  energy  \
# artist
# 2Baba                   6             6             6       6
# ...

# %%
data.groupby('artist')['artist'].count()
# Out:
# artist
# 2Baba            6
# 9ice             3
# AYLÃ            4
# Adekunle Gold    4
# Afro B           1
#                 ..
# Yemi Alade       7
# Yung L           1
# Zlatan           1
# chike            1
# prettyboydo      2
# Name: artist, Length: 171, dtype: int64

# %%
data.groupby('artist').first()
# Out:
#                           name                   album artist_top_genre  \
# artist
# 2Baba            African Queen  Nigeria Gold (YouTube)   afro dancehall
# 9ice                 Gongo Aso               Gongo Aso   afro dancehall
# AYLÃ                    LITT!                   LITT!        indie r&b
# Adekunle Gold        Only Girl               Only Girl   afro dancehall
# Afro B         Drogba (Joanna)         Drogba (Joanna)        afroswing
# ...                        ...                     ...              ...
# Yemi Alade          Koffi Anan              Koffi Anan   afro dancehall
# Yung L                     Sos                     Sos          afropop
# Zlatan              Killin Dem              Killin Dem   afro dancehall
# chike                     Amen      Boo of the Booless     nigerian pop
# prettyboydo            Pull Up       Everything Pretty     nigerian pop
#
#                release_date  length  popularity  danceability  acousticness  \
# artist
# ...

# %%
data1 = data.iloc[0:500]

data1
# Out:
#                                                   name  \
# 0                                               Sparky
# 1                                           shuga rush
# 2                                                LITT!
# 3                             Confident / Feeling Cool
# 4                                           wanted you
# ..                                                 ...
# 495                           Ori Owo (feat. Tillaman)
# 496                                               Ukwu
# 497                                          Eledumare
# 498                                              Sukus
# 499  Adaobi (feat. Don Jazzy, Di'ja, Reekado Banks ...
#
#                                                  album               artist  \
# 0                                   Mandy & The Jungle        Cruel Santino
# 1                         EVERYTHING YOU HEARD IS TRUE  Odunsi (The Engine)
# ...

# %%
data.duplicated().any()
# Out:
# False

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(7,4))
           
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
dataa = pd.DataFrame({'unit':['MANCITY', 'CHELSEA', 'MANUNITED', 'ARSNAL', 'LIVERPOOL'],
                    'count': [43,34,23,33,54]})

dataa
# Out:
#         unit  count
# 0    MANCITY     43
# 1    CHELSEA     34
# 2  MANUNITED     23
# 3     ARSNAL     33
# 4  LIVERPOOL     54

# %%
import pandas as pd
import numpy as np
import sklearn
from scipy import stats
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
sns.barplot(data=dataa, x='unit', y='count')
plt.xlabel('dataa')
# Out:
# Text(0.5, 0, 'dataa')

# %%
# Out:
# Text(0.5, 0, 'dataa')
